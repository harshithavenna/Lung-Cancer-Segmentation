# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tqdm import tqdm
import os
from cv2 import imread, createCLAHE
import cv2
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt

image_path = os.path.join("../input/data/Lung Segmentation/CXR_png")
mask_path = os.path.join("../input/data/Lung Segmentation/","masks/")

# %% [markdown]
# They can inspected the concerning dataset seperately [here](http://https://www.kaggle.com/kmader/pulmonary-chest-xray-abnormalities/home).

# %%
# we have 704 masks but 800 images. Hence we are going to
# make a 1-1 correspondance from mask to images, not the usual other way.
images = os.listdir(image_path)
mask = os.listdir(mask_path)
mask = [fName.split(".png")[0] for fName in mask]
image_file_name = [fName.split("_mask")[0] for fName in mask]

# %%
check = [i for i in mask if "mask" in i]
print("Total mask that has modified name:",len(check))
# Out:
# Total mask that has modified name: 566

# %% [markdown]
# Earlier I was going to train on the Shenzhen dataset while perform prediction on the Montgomery dataset. However, the nature of the data was diffrent in both the set. The images from Shenzhen dataset had smaller lung-to-image ratio as compared to the Montgomery dataset.
#
# Thus, I am loading the two dataset seperately which I combined once I got to know about the disparity.

# %%
testing_files = set(os.listdir(image_path)) & set(os.listdir(mask_path))
training_files = check

def getData(X_shape, flag = "test"):
    im_array = []
    mask_array = []

    if flag == "test":
        for i in tqdm(testing_files):
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

    if flag == "train":
        for i in tqdm(training_files):
            im = cv2.resize(cv2.imread(os.path.join(image_path,i.split("_mask")[0]+".png")),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i+".png")),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

# %%
#perform sanity check

def plotMask(X,y):
    sample = []

    for i in range(6):
        left = X[i]
        right = y[i]
        combined = np.hstack((left,right))
        sample.append(combined)


    for i in range(0,6,3):

        plt.figure(figsize=(25,10))

        plt.subplot(2,3,1+i)
        plt.imshow(sample[i])

        plt.subplot(2,3,2+i)
        plt.imshow(sample[i+1])


        plt.subplot(2,3,3+i)
        plt.imshow(sample[i+2])

        plt.show()

# %%
# Load training and testing data
dim = 256*2
X_train,y_train = getData(dim,flag="train")
X_test, y_test = getData(dim)
# Out:
# 100%|██████████| 566/566 [01:55<00:00,  4.67it/s]
# 100%|██████████| 138/138 [01:07<00:00,  2.10it/s]

# %% [markdown]
# # Perform Sanity Check
#
# It is prudent to perform sanity check of the data correspondance. It become a routine check-up after a while but it is very crucial to check if we had made a mistake in loading the data.

# %%
print("training set")
plotMask(X_train,y_train)
print("testing set")
plotMask(X_test,y_test)
# Out:
# training set
# testing set

# %% [markdown]
# Both the sets looks correct. Let's combine them and further use them as a unified dataset.

# %%
X_train = np.array(X_train).reshape(len(X_train),dim,dim,1)
y_train = np.array(y_train).reshape(len(y_train),dim,dim,1)
X_test = np.array(X_test).reshape(len(X_test),dim,dim,1)
y_test = np.array(y_test).reshape(len(y_test),dim,dim,1)
assert X_train.shape == y_train.shape
assert X_test.shape == y_test.shape
images = np.concatenate((X_train,X_test),axis=0)
mask  = np.concatenate((y_train,y_test),axis=0)

# %% [markdown]
# ## Define  the network and callbacks
#
# I am going to use my favourite segmentation network - U-Nets. You can read about them [here](https://arxiv.org/abs/1505.04597).

# %%
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler


def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256,256,1)):
    inputs = Input(input_size)

    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Compile and train the Unet Model

# %%
model = unet(input_size=(512,512,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss,
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 512, 512, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 128 147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 512, 512, 64) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 512, 512, 32) 18464       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 512, 512, 1)  33          conv2d_18[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Callbacks, Early Stopping and Reduced LR

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                   patience=3,
                                   verbose=1, mode='min', epsilon=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss",
                      mode="min",
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]
# Out:
# /opt/conda/lib/python3.6/site-packages/Keras-2.2.4-py3.6.egg/keras/callbacks.py:1334: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %% [markdown]
# #### Train the model
#
# I intially used a 60-40 train-test spit and got a loss of -0.97. However, the better way to do it is 80-10-10 train-test-validation spit. Below I am roughly doing the later.

# %%
from IPython.display import clear_output
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split

model.compile(optimizer=Adam(lr=2e-4),
              loss=[dice_coef_loss],
           metrics = [dice_coef, 'binary_accuracy'])

train_vol, validation_vol, train_seg, validation_seg = train_test_split((images-127.0)/127.0,
                                                            (mask>127).astype(np.float32),
                                                            test_size = 0.1,random_state = 2018)

train_vol, test_vol, train_seg, test_seg = train_test_split(train_vol,train_seg,
                                                            test_size = 0.1,
                                                            random_state = 2018)

loss_history = model.fit(x = train_vol,
                       y = train_seg,
                         batch_size = 16,
                  epochs = 40,
                  validation_data =(test_vol,test_seg) ,
                  callbacks=callbacks_list)
# Out:
# Train on 569 samples, validate on 64 samples
# Epoch 1/40
# 569/569 [==============================] - 31s 54ms/step - loss: -0.3765 - dice_coef: 0.3765 - binary_accuracy: 0.7242 - val_loss: -0.4071 - val_dice_coef: 0.4071 - val_binary_accuracy: 0.2557
#
# Epoch 00001: val_loss improved from inf to -0.40707, saving model to cxr_reg_weights.best.hdf5
# Epoch 2/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.5560 - dice_coef: 0.5560 - binary_accuracy: 0.6236 - val_loss: -0.6690 - val_dice_coef: 0.6690 - val_binary_accuracy: 0.8040
#
# Epoch 00002: val_loss improved from -0.40707 to -0.66897, saving model to cxr_reg_weights.best.hdf5
# Epoch 3/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.7784 - dice_coef: 0.7784 - binary_accuracy: 0.8828 - val_loss: -0.8555 - val_dice_coef: 0.8555 - val_binary_accuracy: 0.9313
#
# Epoch 00003: val_loss improved from -0.66897 to -0.85547, saving model to cxr_reg_weights.best.hdf5
# Epoch 4/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.8744 - dice_coef: 0.8744 - binary_accuracy: 0.9370 - val_loss: -0.9141 - val_dice_coef: 0.9141 - val_binary_accuracy: 0.9567
#
# Epoch 00004: val_loss improved from -0.85547 to -0.91414, saving model to cxr_reg_weights.best.hdf5
# Epoch 5/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9072 - dice_coef: 0.9072 - binary_accuracy: 0.9535 - val_loss: -0.9263 - val_dice_coef: 0.9263 - val_binary_accuracy: 0.9622
#
# Epoch 00005: val_loss improved from -0.91414 to -0.92631, saving model to cxr_reg_weights.best.hdf5
# Epoch 6/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9184 - dice_coef: 0.9184 - binary_accuracy: 0.9590 - val_loss: -0.9270 - val_dice_coef: 0.9270 - val_binary_accuracy: 0.9629
#
# Epoch 00006: val_loss improved from -0.92631 to -0.92700, saving model to cxr_reg_weights.best.hdf5
# Epoch 7/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9247 - dice_coef: 0.9247 - binary_accuracy: 0.9623 - val_loss: -0.9408 - val_dice_coef: 0.9408 - val_binary_accuracy: 0.9704
#
# Epoch 00007: val_loss improved from -0.92700 to -0.94078, saving model to cxr_reg_weights.best.hdf5
# Epoch 8/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9360 - dice_coef: 0.9360 - binary_accuracy: 0.9678 - val_loss: -0.9474 - val_dice_coef: 0.9474 - val_binary_accuracy: 0.9735
#
# Epoch 00008: val_loss improved from -0.94078 to -0.94739, saving model to cxr_reg_weights.best.hdf5
# Epoch 9/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9422 - dice_coef: 0.9422 - binary_accuracy: 0.9710 - val_loss: -0.9512 - val_dice_coef: 0.9512 - val_binary_accuracy: 0.9751
#
# Epoch 00009: val_loss improved from -0.94739 to -0.95115, saving model to cxr_reg_weights.best.hdf5
# Epoch 10/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9375 - dice_coef: 0.9375 - binary_accuracy: 0.9684 - val_loss: -0.9396 - val_dice_coef: 0.9396 - val_binary_accuracy: 0.9704
#
# Epoch 00010: val_loss did not improve from -0.95115
# Epoch 11/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9419 - dice_coef: 0.9419 - binary_accuracy: 0.9710 - val_loss: -0.9531 - val_dice_coef: 0.9531 - val_binary_accuracy: 0.9764
#
# Epoch 00011: val_loss improved from -0.95115 to -0.95305, saving model to cxr_reg_weights.best.hdf5
# Epoch 12/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9462 - dice_coef: 0.9462 - binary_accuracy: 0.9731 - val_loss: -0.9440 - val_dice_coef: 0.9440 - val_binary_accuracy: 0.9727
#
# Epoch 00012: val_loss did not improve from -0.95305
# Epoch 13/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9456 - dice_coef: 0.9456 - binary_accuracy: 0.9728 - val_loss: -0.9572 - val_dice_coef: 0.9572 - val_binary_accuracy: 0.9783
#
# Epoch 00013: val_loss improved from -0.95305 to -0.95717, saving model to cxr_reg_weights.best.hdf5
# Epoch 14/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9502 - dice_coef: 0.9502 - binary_accuracy: 0.9751 - val_loss: -0.9565 - val_dice_coef: 0.9565 - val_binary_accuracy: 0.9782
#
# Epoch 00014: val_loss did not improve from -0.95717
# Epoch 15/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9517 - dice_coef: 0.9517 - binary_accuracy: 0.9759 - val_loss: -0.9586 - val_dice_coef: 0.9586 - val_binary_accuracy: 0.9789
#
# Epoch 00015: val_loss improved from -0.95717 to -0.95862, saving model to cxr_reg_weights.best.hdf5
# Epoch 16/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9457 - dice_coef: 0.9457 - binary_accuracy: 0.9727 - val_loss: -0.9496 - val_dice_coef: 0.9496 - val_binary_accuracy: 0.9745
#
# Epoch 00016: val_loss did not improve from -0.95862
# Epoch 17/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9505 - dice_coef: 0.9505 - binary_accuracy: 0.9752 - val_loss: -0.9611 - val_dice_coef: 0.9611 - val_binary_accuracy: 0.9803
#
# Epoch 00017: val_loss improved from -0.95862 to -0.96108, saving model to cxr_reg_weights.best.hdf5
# Epoch 18/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9545 - dice_coef: 0.9545 - binary_accuracy: 0.9772 - val_loss: -0.9619 - val_dice_coef: 0.9619 - val_binary_accuracy: 0.9807
#
# Epoch 00018: val_loss improved from -0.96108 to -0.96192, saving model to cxr_reg_weights.best.hdf5
# Epoch 19/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9565 - dice_coef: 0.9565 - binary_accuracy: 0.9782 - val_loss: -0.9625 - val_dice_coef: 0.9625 - val_binary_accuracy: 0.9812
#
# Epoch 00019: val_loss improved from -0.96192 to -0.96248, saving model to cxr_reg_weights.best.hdf5
# Epoch 20/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9569 - dice_coef: 0.9569 - binary_accuracy: 0.9784 - val_loss: -0.9641 - val_dice_coef: 0.9641 - val_binary_accuracy: 0.9818
#
# Epoch 00020: val_loss improved from -0.96248 to -0.96410, saving model to cxr_reg_weights.best.hdf5
# Epoch 21/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9569 - dice_coef: 0.9569 - binary_accuracy: 0.9784 - val_loss: -0.9624 - val_dice_coef: 0.9624 - val_binary_accuracy: 0.9811
#
# Epoch 00021: val_loss did not improve from -0.96410
# Epoch 22/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9581 - dice_coef: 0.9581 - binary_accuracy: 0.9789 - val_loss: -0.9638 - val_dice_coef: 0.9638 - val_binary_accuracy: 0.9819
#
# Epoch 00022: val_loss did not improve from -0.96410
# Epoch 23/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9563 - dice_coef: 0.9563 - binary_accuracy: 0.9782 - val_loss: -0.9636 - val_dice_coef: 0.9636 - val_binary_accuracy: 0.9817
#
# Epoch 00023: val_loss did not improve from -0.96410
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 24/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9594 - dice_coef: 0.9594 - binary_accuracy: 0.9796 - val_loss: -0.9659 - val_dice_coef: 0.9659 - val_binary_accuracy: 0.9828
#
# Epoch 00024: val_loss improved from -0.96410 to -0.96591, saving model to cxr_reg_weights.best.hdf5
# Epoch 25/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9607 - dice_coef: 0.9607 - binary_accuracy: 0.9803 - val_loss: -0.9654 - val_dice_coef: 0.9654 - val_binary_accuracy: 0.9825
#
# Epoch 00025: val_loss did not improve from -0.96591
# Epoch 26/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9612 - dice_coef: 0.9612 - binary_accuracy: 0.9806 - val_loss: -0.9655 - val_dice_coef: 0.9655 - val_binary_accuracy: 0.9825
#
# Epoch 00026: val_loss did not improve from -0.96591
# Epoch 27/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9614 - dice_coef: 0.9614 - binary_accuracy: 0.9807 - val_loss: -0.9661 - val_dice_coef: 0.9661 - val_binary_accuracy: 0.9831
#
# Epoch 00027: val_loss improved from -0.96591 to -0.96614, saving model to cxr_reg_weights.best.hdf5
# Epoch 28/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9613 - dice_coef: 0.9613 - binary_accuracy: 0.9806 - val_loss: -0.9665 - val_dice_coef: 0.9665 - val_binary_accuracy: 0.9830
#
# Epoch 00028: val_loss improved from -0.96614 to -0.96651, saving model to cxr_reg_weights.best.hdf5
# Epoch 29/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9622 - dice_coef: 0.9622 - binary_accuracy: 0.9810 - val_loss: -0.9668 - val_dice_coef: 0.9668 - val_binary_accuracy: 0.9832
#
# Epoch 00029: val_loss improved from -0.96651 to -0.96680, saving model to cxr_reg_weights.best.hdf5
# Epoch 30/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9624 - dice_coef: 0.9624 - binary_accuracy: 0.9811 - val_loss: -0.9672 - val_dice_coef: 0.9672 - val_binary_accuracy: 0.9835
#
# Epoch 00030: val_loss improved from -0.96680 to -0.96722, saving model to cxr_reg_weights.best.hdf5
# Epoch 31/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9624 - dice_coef: 0.9624 - binary_accuracy: 0.9812 - val_loss: -0.9673 - val_dice_coef: 0.9673 - val_binary_accuracy: 0.9835
#
# Epoch 00031: val_loss improved from -0.96722 to -0.96728, saving model to cxr_reg_weights.best.hdf5
# Epoch 32/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9625 - dice_coef: 0.9625 - binary_accuracy: 0.9813 - val_loss: -0.9671 - val_dice_coef: 0.9671 - val_binary_accuracy: 0.9834
#
# Epoch 00032: val_loss did not improve from -0.96728
# Epoch 33/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9628 - dice_coef: 0.9628 - binary_accuracy: 0.9814 - val_loss: -0.9658 - val_dice_coef: 0.9658 - val_binary_accuracy: 0.9826
#
# Epoch 00033: val_loss did not improve from -0.96728
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 34/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9634 - dice_coef: 0.9634 - binary_accuracy: 0.9817 - val_loss: -0.9672 - val_dice_coef: 0.9672 - val_binary_accuracy: 0.9834
#
# Epoch 00034: val_loss did not improve from -0.96728
# Epoch 35/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9641 - dice_coef: 0.9641 - binary_accuracy: 0.9820 - val_loss: -0.9679 - val_dice_coef: 0.9679 - val_binary_accuracy: 0.9838
#
# Epoch 00035: val_loss improved from -0.96728 to -0.96786, saving model to cxr_reg_weights.best.hdf5
# Epoch 36/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9643 - dice_coef: 0.9643 - binary_accuracy: 0.9821 - val_loss: -0.9677 - val_dice_coef: 0.9677 - val_binary_accuracy: 0.9837
#
# Epoch 00036: val_loss did not improve from -0.96786
# Epoch 37/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9644 - dice_coef: 0.9644 - binary_accuracy: 0.9822 - val_loss: -0.9679 - val_dice_coef: 0.9679 - val_binary_accuracy: 0.9839
#
# Epoch 00037: val_loss improved from -0.96786 to -0.96795, saving model to cxr_reg_weights.best.hdf5
# Epoch 38/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9645 - dice_coef: 0.9645 - binary_accuracy: 0.9822 - val_loss: -0.9673 - val_dice_coef: 0.9673 - val_binary_accuracy: 0.9834
#
# Epoch 00038: val_loss did not improve from -0.96795
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 39/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9648 - dice_coef: 0.9648 - binary_accuracy: 0.9824 - val_loss: -0.9679 - val_dice_coef: 0.9679 - val_binary_accuracy: 0.9838
#
# Epoch 00039: val_loss improved from -0.96795 to -0.96795, saving model to cxr_reg_weights.best.hdf5
# Epoch 40/40
# 569/569 [==============================] - 21s 37ms/step - loss: -0.9650 - dice_coef: 0.9650 - binary_accuracy: 0.9825 - val_loss: -0.9673 - val_dice_coef: 0.9673 - val_binary_accuracy: 0.9835
#
# Epoch 00040: val_loss did not improve from -0.96795

# %% [markdown]
# ## Plot the metric and evaluate

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
ax1.plot(loss_history.history['loss'], '-', label = 'Loss')
ax1.plot(loss_history.history['val_loss'], '-', label = 'Validation Loss')
ax1.legend()

ax2.plot(100*np.array(loss_history.history['binary_accuracy']), '-',
         label = 'Accuracy')
ax2.plot(100*np.array(loss_history.history['val_binary_accuracy']), '-',
         label = 'Validation Accuracy')
ax2.legend()

# %% [markdown]
# ## Test the model

# %%
pred_candidates = np.random.randint(1,validation_vol.shape[0],10)
preds = model.predict(validation_vol)

plt.figure(figsize=(20,10))

for i in range(0,9,3):
    plt.subplot(3,3,i+1)

    plt.imshow(np.squeeze(validation_vol[pred_candidates[i]]))
    plt.xlabel("Base Image")


    plt.subplot(3,3,i+2)
    plt.imshow(np.squeeze(validation_seg[pred_candidates[i]]))
    plt.xlabel("Mask")

    plt.subplot(3,3,i+3)
    plt.imshow(np.squeeze(preds[pred_candidates[i]]))
    plt.xlabel("Pridiction")
